# %%
import pandas as pd

# Loads the dataset and skips the first 9 rows (not needed)
df = pd.read_excel('gov_10a_exp__custom_4037524_spreadsheet.xlsx',
                   sheet_name = 'Sheet 1', skiprows = 9)

# Dataset contains some flags, visualized as collumns, which get removed
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# Removing the last 6 rows (not needed)
df.drop(df.tail(6).index,inplace = True)

# Removing first row since it contains no data
df.drop(index = 0, inplace = True)

# Replacing broken header names with their actual name
df.rename(columns={'TIME': 'Country', 'TIME.1': 'UNIT'}, inplace = True)

# Setting the dataframe index to 'Country'
df.set_index('Country')
# Out:
# /home/elias/anaconda3/envs/Default/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                                                  UNIT  \
# Country
# European Union - 27 countries (from 2020)                                Million euro
# European Union - 27 countries (from 2020)  Percentage of gross domestic product (GDP)
# Euro area - 19 countries  (from 2015)                                    Million euro
# Euro area - 19 countries  (from 2015)      Percentage of gross domestic product (GDP)
# Belgium                                                                  Million euro
# ...                                                                               ...
# Iceland                                    Percentage of gross domestic product (GDP)
# Norway                                                                   Million euro
# Norway                                     Percentage of gross domestic product (GDP)
# Switzerland                                                              Million euro
# Switzerland                                Percentage of gross domestic product (GDP)
#
#                                                 2012       2013       2014  \
# Country
# European Union - 27 countries (from 2020)  5660949.1  5709529.5  5770198.1
# European Union - 27 countries (from 2020)       49.7       49.6       49.0
# Euro area - 19 countries  (from 2015)      4918492.7  4960347.2  5012826.4
# Euro area - 19 countries  (from 2015)           50.0       49.9       49.3
# Belgium                                     218102.2   220470.1   224069.3
# ...                                              ...        ...        ...
# Iceland                                         47.7       46.0       45.8
# Norway                                      171737.9   174704.3   173878.8
# Norway                                          43.3       44.4       46.3
# Switzerland                                 174564.1   178817.2   182302.8
# Switzerland                                     32.4       33.3       32.9
#
#                                                 2015       2016       2017  \
# Country
# European Union - 27 countries (from 2020)  5874466.9  5942333.4  6105736.5
# European Union - 27 countries (from 2020)       48.1       47.4       46.7
# Euro area - 19 countries  (from 2015)      5095520.2  5163761.1  5289227.9
# Euro area - 19 countries  (from 2015)           48.4       47.7       47.1
# Belgium                                     223850.3   228451.6   231561.0
# ...                                              ...        ...        ...
# Iceland                                         43.5       46.4       44.4
# Norway                                      171314.2   171850.5   178344.8
# Norway                                          49.3       51.5       50.5
# Switzerland                                 210265.0   209361.3   207556.6
# Switzerland                                     33.2       33.3       33.3
#
#                                                 2018       2019       2020  \
# Country
# European Union - 27 countries (from 2020)  6295433.4  6520557.3  7118015.8
# European Union - 27 countries (from 2020)       46.5       46.5       52.9
# Euro area - 19 countries  (from 2015)      5436975.8  5622101.3  6129243.0
# Euro area - 19 countries  (from 2015)           46.9       46.9       53.5
# Belgium                                     240313.6   247898.6   270409.9
# ...                                              ...        ...        ...
# Iceland                                         43.8       43.3       50.5
# Norway                                      180787.3   186483.0   186193.9
# Norway                                          48.8       51.6       58.5
# Switzerland                                 202574.1   214206.6   249177.4
# Switzerland                                     32.5       32.8       37.8
#
#                                           2021
# Country
# European Union - 27 countries (from 2020)    :
# European Union - 27 countries (from 2020)    :
# Euro area - 19 countries  (from 2015)        :
# Euro area - 19 countries  (from 2015)        :
# Belgium                                      :
# ...                                        ...
# Iceland                                      :
# Norway                                       :
# Norway                                       :
# Switzerland                                  :
# Switzerland                                  :
#
# [64 rows x 11 columns]

# %%
# Displaying all entries where 'Country' collumn is 'Greece'
df.loc[df['Country'] == 'Greece']
# Out:
#    Country                                        UNIT      2012      2013  \
# 19  Greece                                Million euro  106844.0  112926.0
# 20  Greece  Percentage of gross domestic product (GDP)      56.7      62.8
#
#        2014     2015     2016     2017     2018     2019     2020 2021
# 19  89913.0  95336.0  87154.0  85871.0  87137.0  87758.0  98871.0    :
# 20     50.7     54.1     49.9     48.5     48.5     47.9     59.8    :
