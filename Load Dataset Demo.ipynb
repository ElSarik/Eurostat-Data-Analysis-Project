# %% [markdown]
# # Imports - Run first

# %%
import pandas as pd
from IPython.display import display
import warnings

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

warnings.simplefilter("ignore")

# %% [markdown]
# # Step-by-step execution

# %%
# Loads column 'C' of the 6th row of the dataset
sheet_information = pd.read_excel('gov_10a_exp__custom_4037524_spreadsheet.xlsx',
                               sheet_name = 'Sheet 1', skiprows = 5, nrows = 1,
                              usecols = 'C')

# The sector is the column name of the dataframe, and its only row should be the category name
sector = sheet_information.columns.values[0]
category = sheet_information[sector].iloc[0]

category
# Out:
# 'Total'

# %%
# Loads the dataset and skips the first 9 rows (not needed)
df = pd.read_excel('gov_10a_exp__custom_4037524_spreadsheet.xlsx',
                   sheet_name = 'Sheet 1', skiprows = 9)

# Dataset contains some flags, visualized as collumns, which get removed
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# Removing the last 6 rows (not needed)
df.drop(df.tail(6).index,inplace = True)

# Removing first row since it contains no data
df.drop(index = 0, inplace = True)

# Replacing broken header names with their actual name
df.rename(columns={'TIME': 'Country', 'TIME.1': 'UNIT'}, inplace = True)

df_before = df.loc[df['Country'] == 'Greece']

df
# Out:
#                                              Country  \
# 1          European Union - 27 countries (from 2020)
# 2          European Union - 27 countries (from 2020)
# 3              Euro area - 19 countries  (from 2015)
# 4              Euro area - 19 countries  (from 2015)
# 5                                            Belgium
# 6                                            Belgium
# 7                                           Bulgaria
# 8                                           Bulgaria
# 9                                            Czechia
# 10                                           Czechia
# 11                                           Denmark
# 12                                           Denmark
# 13  Germany (until 1990 former territory of the FRG)
# 14  Germany (until 1990 former territory of the FRG)
# 15                                           Estonia
# 16                                           Estonia
# 17                                           Ireland
# 18                                           Ireland
# 19                                            Greece
# 20                                            Greece
# 21                                             Spain
# 22                                             Spain
# 23                                            France
# 24                                            France
# 25                                           Croatia
# 26                                           Croatia
# 27                                             Italy
# 28                                             Italy
# 29                                            Cyprus
# 30                                            Cyprus
# 31                                            Latvia
# 32                                            Latvia
# 33                                         Lithuania
# 34                                         Lithuania
# 35                                        Luxembourg
# 36                                        Luxembourg
# 37                                           Hungary
# 38                                           Hungary
# 39                                             Malta
# 40                                             Malta
# 41                                       Netherlands
# 42                                       Netherlands
# 43                                           Austria
# 44                                           Austria
# 45                                            Poland
# 46                                            Poland
# 47                                          Portugal
# 48                                          Portugal
# 49                                           Romania
# 50                                           Romania
# 51                                          Slovenia
# 52                                          Slovenia
# 53                                          Slovakia
# 54                                          Slovakia
# 55                                           Finland
# 56                                           Finland
# 57                                            Sweden
# 58                                            Sweden
# 59                                           Iceland
# 60                                           Iceland
# 61                                            Norway
# 62                                            Norway
# 63                                       Switzerland
# 64                                       Switzerland
#
#                                           UNIT       2012       2013  \
# 1                                 Million euro  5660949.1  5709529.5
# 2   Percentage of gross domestic product (GDP)       49.7       49.6
# 3                                 Million euro  4918492.7  4960347.2
# 4   Percentage of gross domestic product (GDP)       50.0       49.9
# 5                                 Million euro   218102.2   220470.1
# 6   Percentage of gross domestic product (GDP)       56.5       56.1
# 7                                 Million euro    14475.6    15879.2
# 8   Percentage of gross domestic product (GDP)       34.3       37.8
# 53    33028.6    36508.2    34574.9    33440.3    35615.0    38240.7
# 54       43.4       45.7       42.7       39.6       39.8       40.7
# 55   118504.0   119415.0   121044.0   121375.0   124491.0   127809.0
# 56       57.3       56.5       55.6       53.6       53.3       53.3
# 57   222499.9   224737.7   231790.1   236338.7   234636.1   234314.3
# 58       50.7       49.3       49.7       49.2       49.9       49.1
# 59     6174.1     6866.8     8732.2     9733.5     9751.1     9617.2
# 60       45.8       43.5       46.4       44.4       43.8       43.3
# 61   173878.8   171314.2   171850.5   178344.8   180787.3   186483.0
# 62       46.3       49.3       51.5       50.5       48.8       51.6
# 63   182302.8   210265.0   209361.3   207556.6   202574.1   214206.6
# 64       32.9       33.2       33.3       33.3       32.5       32.8
#
#          2020      2021
# 1   7118015.8         :
# 2        52.9         :
# 3   6129243.0         :
# 4        53.5         :
# 5    270409.9         :
# 6        59.2         :
# 7     25636.0         :
# 8        41.8         :
# 9    101648.8         :
# 10       47.2         :
# 11   166991.6         :
# 12       53.4         :
# 13  1712131.0         :
# 14       50.8         :
# 15    12313.1         :
# 16       45.9         :
# 17   102032.8         :
# 18       27.4         :
# 19    98871.0         :
# 20       59.8         :
# 21   588279.0         :
# 22       52.4         :
# 23  1419593.0         :
# 24       61.6         :
# 25    27367.5         :
# 26       54.5         :
# 27   944486.0         :
# 28       57.1         :
# 29     9724.2         :
# 30       45.1         :
# 31    12726.5         :
# 32       43.1         :
# 33    21233.8         :
# 34       42.9         :
# 35    30297.4         :
# 36       47.2         :
# 37    70455.8         :
# 38       51.6         :
# 39     6001.8         :
# 40       45.9         :
# 41   384443.0         :
# 42       48.0         :
# 43   216207.5  227261.6
# 44       56.7        56
# 45   254864.3         :
# 46       48.7         :
# 47    98725.0         :
# 48       49.3         :
# 49    91583.4         :
# 50       41.5         :
# 51    24079.2         :
# 52       51.3         :
# 53    41943.9         :
# 54       45.6         :
# 55   135745.0         :
# 56       57.5         :
# 57   250225.4         :
# 58       52.1         :
# 59     9610.1         :
# 60       50.5         :
# 61   186193.9         :
# 62       58.5         :
# 63   249177.4         :
# 64       37.8         :

# %%
# Extracting the Year columns
year_list=list(test.columns)
year_list.remove('Country')
year_list.remove('UNIT')

# Splitting the data based on the measurement unit and also adding the category name
gdp = df.loc[df['UNIT'] == 'Percentage of gross domestic product (GDP)']
gdp = pd.melt(gdp, id_vars = ['Country'], value_vars = year_list, var_name = 'Year', value_name = '% GDP', ignore_index=False)
gdp = gdp.sort_values(by = ['Country', 'Year']).reset_index(drop = True)
gdp['Category'] = category

millions = df.loc[df['UNIT'] == 'Million euro']
millions = pd.melt(millions, id_vars = ['Country'], value_vars = year_list, var_name = 'Year', value_name = 'Million euro', ignore_index=False)
millions = millions.sort_values(by = ['Country', 'Year']).reset_index(drop = True)

# Merging the necessary data
df = millions
df['% GDP'] = gdp['% GDP']
df['Category'] = gdp['Category']

df
# Out:
#                                               Country  Year Million euro  \
# 0                                             Austria  2012     163191.9
# 1                                             Austria  2013     167292.1
# 2                                             Austria  2014     174671.6
# 312                                       Switzerland  2014     182302.8
# 313                                       Switzerland  2015     210265.0
# 314                                       Switzerland  2016     209361.3
# 315                                       Switzerland  2017     207556.6
# 316                                       Switzerland  2018     202574.1
# 317                                       Switzerland  2019     214206.6
# 318                                       Switzerland  2020     249177.4
# 319                                       Switzerland  2021            :
#
#     % GDP Category
# 0    51.2    Total
# 1    51.6    Total
# 2    52.4    Total
# 3    51.1    Total
# 4    50.1    Total
# 5    49.3    Total
# 6    48.8    Total
# 7    48.6    Total
# 8    56.7    Total
# 9      56    Total
# 10   56.5    Total
# 11   56.1    Total
# 12   55.6    Total
# 13   53.7    Total
# 14   53.1    Total
# 15   52.0    Total
# 16   52.2    Total
# 17   51.8    Total
# 18   59.2    Total
# 19      :    Total
# 20   34.3    Total
# 21   37.8    Total
# 22   43.2    Total
# 23   40.4    Total
# 24   34.8    Total
# 25   34.8    Total
# 26   36.9    Total
# 27   35.5    Total
# 28   41.8    Total
# 29      :    Total
# 30   48.4    Total
# 31   48.3    Total
# 32   48.7    Total
# 33   48.2    Total
# 34   46.9    Total
# 35   44.7    Total
# 36   45.5    Total
# 37   46.0    Total
# 38   54.5    Total
# 39      :    Total
# 40   42.2    Total
# 41   43.0    Total
# 42   49.4    Total
# 43   40.6    Total
# 44   37.5    Total
# 45   36.5    Total
# 46   42.7    Total
# 47   38.4    Total
# 48   45.1    Total
# 49      :    Total
# 50   44.7    Total
# 51   42.7    Total
# 52   42.6    Total
# 53   41.9    Total
# 54   39.8    Total
# 55   39.0    Total
# 56   40.6    Total
# 57   41.1    Total
# 58   47.2    Total
# 59      :    Total
# 60   58.0    Total
# 61   55.8    Total
# 62   55.2    Total
# 63   54.5    Total
# 64   52.5    Total
# 65   50.5    Total
# 66   50.5    Total
# 67   49.5    Total
# 68   53.4    Total
# 69      :    Total
# 70   39.2    Total
# 71   38.4    Total
# 72   37.8    Total
# 73   39.5    Total
# 74   39.4    Total
# 75   39.2    Total
# 76   39.4    Total
# 77   39.4    Total
# 78   45.9    Total
# 79      :    Total
# 80   50.0    Total
# 81   49.9    Total
# 82   49.3    Total
# 83   48.4    Total
# 84   47.7    Total
# 85   47.1    Total
# 86   46.9    Total
# 87   46.9    Total
# 88   53.5    Total
# 89      :    Total
# 90   49.7    Total
# 91   49.6    Total
# 92   49.0    Total
# 93   48.1    Total
# 94   47.4    Total
# 95   46.7    Total
# 96   46.5    Total
# 97   46.5    Total
# 98   52.9    Total
# 99      :    Total
# 100  55.4    Total
# 101  56.8    Total
# 102  57.3    Total
# 103  56.5    Total
# 104  55.6    Total
# 105  53.6    Total
# 106  53.3    Total
# 107  53.3    Total
# 108  57.5    Total
# 109     :    Total
# 110  57.1    Total
# 111  57.2    Total
# 112  57.2    Total
# 113  56.8    Total
# 114  56.7    Total
# 115  56.5    Total
# 116  55.6    Total
# 117  55.4    Total
# 118  61.6    Total
# 119     :    Total
# 120  44.9    Total
# 121  44.9    Total
# 122  44.3    Total
# 123  44.1    Total
# 124  44.4    Total
# 266  34.5    Total
# 267  36.0    Total
# 268  41.5    Total
# 269     :    Total
# 270  41.3    Total
# 271  42.6    Total
# 272  43.4    Total
# 273  45.7    Total
# 274  42.7    Total
# 275  39.6    Total
# 276  39.8    Total
# 277  40.7    Total
# 278  45.6    Total
# 279     :    Total
# 280  49.4    Total
# 281  60.3    Total
# 282  50.8    Total
# 283  48.7    Total
# 284  46.2    Total
# 285  44.1    Total
# 286  43.5    Total
# 287  43.3    Total
# 288  51.3    Total
# 289     :    Total
# 290  48.7    Total
# 291  45.8    Total
# 292  45.1    Total
# 293  43.9    Total
# 294  42.4    Total
# 295  41.2    Total
# 296  41.7    Total
# 297  42.1    Total
# 298  52.4    Total
# 299     :    Total
# 300  51.0    Total
# 301  51.7    Total
# 302  50.7    Total
# 303  49.3    Total
# 304  49.7    Total
# 305  49.2    Total
# 306  49.9    Total
# 307  49.1    Total
# 308  52.1    Total
# 309     :    Total
# 310  32.4    Total
# 311  33.3    Total
# 312  32.9    Total
# 313  33.2    Total
# 314  33.3    Total
# 315  33.3    Total
# 316  32.5    Total
# 317  32.8    Total
# 318  37.8    Total
# 319     :    Total

# %%
# Displaying all entries where 'Country' collumn is 'Greece'
df_after = df.loc[df['Country'] == 'Greece']

display(df_before)
display(df_after)
# Out:
#    Country                                        UNIT      2012      2013  \
# 19  Greece                                Million euro  106844.0  112926.0
# 20  Greece  Percentage of gross domestic product (GDP)      56.7      62.8
#
#        2014     2015     2016     2017     2018     2019     2020 2021
# 19  89913.0  95336.0  87154.0  85871.0  87137.0  87758.0  98871.0    :
# 20     50.7     54.1     49.9     48.5     48.5     47.9     59.8    :
#     Country  Year Million euro % GDP Category
# 130  Greece  2012     106844.0  56.7    Total
# 131  Greece  2013     112926.0  62.8    Total
# 132  Greece  2014      89913.0  50.7    Total
# 133  Greece  2015      95336.0  54.1    Total
# 134  Greece  2016      87154.0  49.9    Total
# 135  Greece  2017      85871.0  48.5    Total
# 136  Greece  2018      87137.0  48.5    Total
# 137  Greece  2019      87758.0  47.9    Total
# 138  Greece  2020      98871.0  59.8    Total
# 139  Greece  2021            :     :    Total

# %% [markdown]
# # Row binding of 2 sheets DEMO

# %%
# All of the above code as a function

dataset = pd.DataFrame()

def cleaner(sheet):
    
    global dataset
    
    # Loads column 'C' of the 6th row of the dataset
    sheet_information = pd.read_excel('gov_10a_exp__custom_4037524_spreadsheet.xlsx',
                                   sheet_name = sheet, skiprows = 5, nrows = 1,
                                  usecols = 'C')

    # The sector is the column name of the dataframe, and its only row should be the category name
    sector = sheet_information.columns.values[0]
    category = sheet_information[sector].iloc[0]
    
    # Loads the dataset and skips the first 9 rows (not needed)
    df = pd.read_excel('gov_10a_exp__custom_4037524_spreadsheet.xlsx',
                       sheet_name = sheet, skiprows = 9)

    # Dataset contains some flags, visualized as collumns, which get removed
    df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

    # Removing the last 6 rows (not needed)
    df.drop(df.tail(6).index,inplace = True)

    # Removing first row since it contains no data
    df.drop(index = 0, inplace = True)

    # Replacing broken header names with their actual name
    df.rename(columns={'TIME': 'Country', 'TIME.1': 'UNIT'}, inplace = True)
    
    
    # Extracting the Year columns
    year_list=list(df.columns)
    year_list.remove('Country')
    year_list.remove('UNIT')

    # Splitting the data based on the measurement unit and also adding the category name
    gdp = df.loc[df['UNIT'] == 'Percentage of gross domestic product (GDP)']
    gdp = pd.melt(gdp, id_vars = ['Country'], value_vars = year_list, var_name = 'Year', value_name = '% GDP', ignore_index=False)
    gdp = gdp.sort_values(by = ['Country', 'Year']).reset_index(drop = True)
    gdp['Category'] = category

    millions = df.loc[df['UNIT'] == 'Million euro']
    millions = pd.melt(millions, id_vars = ['Country'], value_vars = year_list, var_name = 'Year', value_name = 'Million euro', ignore_index=False)
    millions = millions.sort_values(by = ['Country', 'Year']).reset_index(drop = True)

    # Merging the necessary data
    df = millions
    df['% GDP'] = gdp['% GDP']
    df['Category'] = gdp['Category']
    
    dataset = pd.concat([dataset, df])

# %%
cleaner('Sheet 1')
cleaner('Sheet 2')
cleaner('Sheet 3')

# %%
dataset.loc[dataset['Country'] == 'Greece']
# Out:
#     Country  Year Million euro % GDP  \
# 130  Greece  2012     106844.0  56.7
# 131  Greece  2013     112926.0  62.8
# 132  Greece  2014      89913.0  50.7
# 133  Greece  2015      95336.0  54.1
# 134  Greece  2016      87154.0  49.9
# 135  Greece  2017      85871.0  48.5
# 136  Greece  2018      87137.0  48.5
# 137  Greece  2019      87758.0  47.9
# 138  Greece  2020      98871.0  59.8
# 139  Greece  2021            :     :
# 130  Greece  2012      20988.0  11.1
# 131  Greece  2013      17794.0   9.9
# 132  Greece  2014      17796.0  10.0
# 133  Greece  2015      17769.0  10.1
# 134  Greece  2016      15553.0   8.9
# 135  Greece  2017      15060.0   8.5
# 136  Greece  2018      15218.0   8.5
# 137  Greece  2019      14548.0   7.9
# 138  Greece  2020      13878.0   8.4
# 139  Greece  2021            :     :
# 130  Greece  2012       3291.0   1.7
# 131  Greece  2013       3409.0   1.9
# 132  Greece  2014       3302.0   1.9
# 133  Greece  2015       3125.0   1.8
# 134  Greece  2016       3307.0   1.9
# 135  Greece  2017       3234.0   1.8
# 136  Greece  2018       3448.0   1.9
# 137  Greece  2019       3151.0   1.7
# 138  Greece  2020       3305.0   2.0
# 139  Greece  2021            :     :
#
#                                               Category
# 130                                              Total
# 131                                              Total
# 132                                              Total
# 133                                              Total
# 134                                              Total
# 135                                              Total
# 136                                              Total
# 137                                              Total
# 138                                              Total
# 139                                              Total
# 130                            General public services
# 131                            General public services
# 132                            General public services
# 133                            General public services
# 134                            General public services
# 135                            General public services
# 136                            General public services
# 137                            General public services
# 138                            General public services
# 139                            General public services
# 130  Executive and legislative organs, financial an...
# 131  Executive and legislative organs, financial an...
# 132  Executive and legislative organs, financial an...
# 133  Executive and legislative organs, financial an...
# 134  Executive and legislative organs, financial an...
# 135  Executive and legislative organs, financial an...
# 136  Executive and legislative organs, financial an...
# 137  Executive and legislative organs, financial an...
# 138  Executive and legislative organs, financial an...
# 139  Executive and legislative organs, financial an...
